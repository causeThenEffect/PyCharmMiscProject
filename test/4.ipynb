# %% [markdown]
# flowchart TD
#     A[Participants<br>Grade 10 EFL Students<br>Two Intact Classes] --> B[Pretest (Week 0)<br>IELTS Speaking Tasks<br>- Fluency<br>- Accuracy<br>- Pronunciation<br>- Complexity]
#     B --> C[Group Assignment]
#     C --> D1[AI Feedback]
#     C --> D2[Teacher Feedback]
#     D1 & D2 --> E[Midtest (Week 6)]
#     E --> F[Posttest (Week 12)]
