# %% [markdown]
# ```markdown
# | 姓名 | 年龄 | 城市 |
# |------|------|------|
# | 张三 | 25   | 深圳 |
# | 李四 | 30   | 北京 |

# %% [markdown]
# # 数据分析报告
#
# ## 1. 背景说明
# 本报告用于分析 **近五年收入变化趋势**。
#
# ## 2. 核心结论
# > 收入呈现稳定上升趋势，2024 年增长最快。
#
# ## 3. 数据概览
#
# | 年份 | 收入 |
# |------|------|
# | 2020 | 10   |
# | 2021 | 12   |
# | 2022 | 15   |
# | 2023 | 18   |
# | 2024 | 22   |
#
# ## 4. 公式
# $$
# 增长率 = \frac{当前值 - 上期值}{上期值}
# $$

# %% [markdown]
# # 📊 项目标题 / Notebook 标题
#
# > 作者：
# > 日期：
# > 环境：Python 3.x / Jupyter Notebook
#
# ---
#
# ## 1️⃣ 背景与目标（Background & Objective）
#
# **研究背景：**
# 简要说明这个 Notebook 是做什么的，为什么要做。
#
# **目标：**
# - 目标 1
# - 目标 2
# - 目标 3
#
# ---
#
# ## 2️⃣ 数据说明（Data Description）
#
# **数据来源：**
# - 文件名 / 数据库 / 接口
# - 时间范围
#
# **字段说明：**
#
# | 字段名 | 含义 | 备注 |
# |------|------|------|
# | col1 | 示例字段 | 可选 |
# | col2 | 示例字段 | 可选 |
#
# ---
#
# ## 3️⃣ 分析思路（Methodology）
#
# 整体分析步骤如下：
#
# 1. 数据读取
# 2. 数据清洗
# 3. 数据分析
# 4. 可视化
# 5. 结论总结
#
# ---
#
# ## 4️⃣ 核心分析（Analysis）
#
# ### 4.1 描述性分析
# - 数据规模
# - 基本统计特征
#
# ### 4.2 关键指标
# 常用公式：
#
# $$
# 增长率 = \frac{本期值 - 上期值}{上期值}
# $$
#
# ---
#
# ## 5️⃣ 可视化结果（Visualization）
#
# > 说明图表含义，例如趋势、异常点等。
#
# - 图 1：趋势图
# - 图 2：对比图
#
# ---
#
# ## 6️⃣ 结论（Conclusion）
#
# **主要结论：**
# - 结论 1
# - 结论 2
# - 结论 3
#
# ---
#
# ## 7️⃣ 不足与改进（Limitations）
#
# - 数据不足之处
# - 方法可改进点
#
# ---
#
# ## 8️⃣ 总结（Summary）
#
# > 用 2～3 句话总结整个 Notebook 的价值和结果。
#
# ---
#
# ## ✅ 附录（Appendix）
# - 参考资料
# - 备注说明
